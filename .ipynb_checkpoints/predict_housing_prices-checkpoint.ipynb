# %% [markdown]
# # Predict housing prices

# %% [markdown]
# ## Background
#
# The [House Prices](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview) dataset from Kaggle has sale prices of residential homes in Ames, Iowa and 79 explanatory variables that may have impact on housing prices. With proper feature engineering and regression techniques, we can reasonably predict the price of every home. Let's model away!

# %% [markdown]
# ## Getting data
# First, we need to query the data from the Thinkful PostgreSQL database.

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as style

# %matplotlib inline
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
from sklearn.linear_model import (
    RidgeCV,
    LassoCV,
    ElasticNetCV,
    Ridge,
    Lasso,
    ElasticNet,
    LinearRegression,
)
from sklearn.model_selection import cross_val_score


style.use("fivethirtyeight")

from sqlalchemy import create_engine
from scipy import stats

import warnings

warnings.filterwarnings("ignore")

# %load_ext lab_black

# %%
# PostgreSQL credentials
postgres_user = "dsbc_student"
postgres_pw = "7*.8G9QH21"
postgres_host = "142.93.121.174"
postgres_port = "5432"
postgres_db = "houseprices"

engine = create_engine(
    "postgresql://{}:{}@{}:{}/{}".format(
        postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db
    )
)
raw = pd.read_sql_query("select * from houseprices", con=engine)

# Close connection after the query
engine.dispose()

# %% [markdown]
# ## Data cleaning
# We need to clean the raw data before using it to build predictive models, no matter what method we use. Particularly, we want to check if the **data type** of each variable matches its description and whether there are **missing values** or **outliers**.
#
# Should we clean data before or after train/test split? It depends on what kind of cleaning. To check data types and missing values, I'd like to inspect the entire dataset. If some variables are represented in a wrong format or if missing values are not labeled corrected, the changes are going to apply to all data uniformly. However, I'll only inspect and potentially deal with outliers after the split since which values are considered outliers depend on other values. The philosophy behind this is that we should treat test data as future data that we don't yet posses; if a decision depends on the exact values of the data, we should only do it based on the training data while being agnostic to the test data.

# %% [markdown]
# ### Clean entire dataset
#
# #### Data type
# How many variables are categorical (discrete) and how many are numeric (continuous)?

# %%
print(
    "The housing price data has {} rows and {} columns.\n".format(
        raw.shape[0], raw.shape[1]
    )
)

discrete_cols = raw.select_dtypes(include=["object"])
continuous_cols = raw.select_dtypes(include=["number"])

print(
    "{} columns contain strings and {} contain numeric values.".format(
        discrete_cols.shape[1], continuous_cols.shape[1]
    )
)
# Out:
# The housing price data has 1460 rows and 81 columns.
#
# 43 columns contain strings and 38 contain numeric values.

# %% [markdown]
# However, not all numeric columns are continuous. According to the [data description](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/download/EGpnHbJBO1XGF5B35WNU%2Fversions%2FHOSha0bPv4HEBGjo9O9x%2Ffiles%2Fdata_description.txt) on Kaggle, "mssubclass" indicates the type of dwelling involved in the sale; while each type is assigned a numeric value, the numbers don't convey continuous quantities but discrete types. By definition, "msssubclass" is a nominal categorical variable. The only other case like this is "id", where a numeric value indicates a unique home.
#
# To ease future use, we can covert "mssubclass" to strings. And since we don't need "id", we can drop it. To avoid modifying the raw data, we can create a new data frame to store cleaned data here and later.

# %%
# Create a new data frame
df = raw.copy()

# Convert mssubclass to string
df["mssubclass"] = df["mssubclass"].astype(str)

# Drop "id"
df.drop("id", axis=1, inplace=True)

# %% [markdown]
# In reality, the housing price data has 44 discrete variables and 36 continuous variables.

# %% [markdown]
# #### Missing data
# Let's find out which columns have missing values and the proportion of data missing in each column.

# %%
# Find columns with missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum() / df.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=["total", "percent"])
missing = missing.loc[missing["total"] > 0, :]

missing
# Out:
#               total   percent
# poolqc         1453  0.995205
# miscfeature    1406  0.963014
# alley          1369  0.937671
# fence          1179  0.807534
# fireplacequ     690  0.472603
# lotfrontage     259  0.177397
# garagetype       81  0.055479
# garagecond       81  0.055479
# garagefinish     81  0.055479
# garagequal       81  0.055479
# garageyrblt      81  0.055479
# bsmtfintype2     38  0.026027
# bsmtexposure     38  0.026027
# bsmtqual         37  0.025342
# bsmtcond         37  0.025342
# bsmtfintype1     37  0.025342
# masvnrarea        8  0.005479
# masvnrtype        8  0.005479
# electrical        1  0.000685

# %% [markdown]
# Among the 19 columns with missing values, six have over 15% data missing. Initially, I wanted to drop these columns altogether. However, after reading the data description again, I realized that some columns use missing values to indicate "none" rather than "unknown", which is quite misleading! For instance, a missing value in "poolqc" means that a house has no pool rather than there's no data on whether it has pools.
#
# Let's replace missing values with a new category called "None" in these columns.

# %%
cols_fillna = [
    "poolqc",
    "miscfeature",
    "alley",
    "fence",
    "masvnrtype",
    "fireplacequ",
    "garagequal",
    "garagecond",
    "garagefinish",
    "garagetype",
    "electrical",
    "kitchenqual",
    "saletype",
    "functional",
    "exterior2nd",
    "exterior1st",
    "bsmtexposure",
    "bsmtcond",
    "bsmtqual",
    "bsmtfintype1",
    "bsmtfintype2",
    "mszoning",
    "utilities",
]

# replace 'NaN' with 'None' in these columns
for col in cols_fillna:
    df[col].fillna("None", inplace=True)

# %% [markdown]
# Let's check for missing values again.

# %%
# Find columns with missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum() / df.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=["total", "percent"])
missing = missing.loc[missing["total"] > 0, :]

missing
# Out:
#              total   percent
# lotfrontage    259  0.177397
# garageyrblt     81  0.055479
# masvnrarea       8  0.005479

# %% [markdown]
# Only 3 columns still have missing values. Since "lotfrontage" has over 18% of the data missing, we can drop this column. For the other two columns, we can wait until feature engineering to decide; whether we want to keep them depends on whether they are informative or not. For a predictive modeling project like this, however, we should cautious about imputing or interpolating missing values as it may change our predictions.

# %%
# Drop lotfronatge from the data
df = df.drop("lotfrontage", axis=1)

# %% [markdown]
# ### Clean test data
# As discussed, if data cleaning depends on the exact values of data, we should do it separately for the training data and the test data. This would include outlier detection and subsequent data exploration and feature engineering.

# %% [markdown]
# #### Train/test split
# We can use 80% of the housing price data to train our models and save up 20% to examine model performance.

# %%
# Y is the target variable that we're are trying to predict
Y = df[df.columns[-1]]

# X is the feature set used to housing prices
X = df[df.columns[:-1]]

# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=465
)

df_train = pd.concat([X_train, y_train.reindex(X_train.index)], axis=1)

df_test = pd.concat([X_test, y_test.reindex(X_test.index)], axis=1)

# %% [markdown]
# #### Outliers
# For continuous variables, we can use box plots to visually detect outliers.

# %%
# Names of continuous variables
continuous_cols = df_train.select_dtypes(include=["number"]).columns

# Generate a boxplot for each variable
plt.figure(figsize=(35, 25))

i = 1
for col in continuous_cols:
    plt.subplot(7, 5, i)
    plt.boxplot(df[col].dropna())
    plt.title("{}".format(col))
    i += 1

plt.tight_layout
plt.show()

# %% [markdown]
# Most variables above have outliers. Like imputing or interpolating missing values, removing outliers or replacing them with "normal" values may change our distributions and therefore possibly the predictions. According to Alvira Swalin's [Medium article](https://heartbeat.fritz.ai/how-to-make-your-machine-learning-models-robust-to-outliers-44d404067d07), we should only drop outliers from measurement errors and if we worry about outliers biasing predictions, we can use modeling approaches (e.g., random forest) that are robust to outliers.
#
# How do we spot measurement errors? We can transform raw values into $Z$-scores; exceptionally high (e.g., +10) or low (e.g., -10) $Z$-scores may indicate such errors. The `StandardScaler` function in scikit-learn allows us to perform $Z$-transformation easily.

# %%
# Transform continuous variables
scaler = preprocessing.StandardScaler().fit(df_train[continuous_cols])

# Generate histograms of Z-scores
plt.figure(figsize=(35, 25))

for i in range(len(continuous_cols)):
    plt.subplot(7, 5, i + 1)
    plt.hist(scaler.transform(df_train[continuous_cols])[:, i])
    plt.title("{}".format(continuous_cols[i]))

plt.tight_layout
plt.show()

# %% [markdown]
# Traditionally, $Z-$scores greater than 3 or smaller than -3 are seen as outliers but they are still likely to be valid. Removing surprising but correctly measured observations may not improve model predictions (see [discussions](https://stats.stackexchange.com/questions/298551/will-removing-outliers-improve-my-predictive-model) on this topic here).
#
# However, $Z$-scores of "real data" are unlikely to be, say, as high as 20 or 30. For example, the variable "lotarea" has outrageous $Z$-values that go above 20. Can a house have a 215,245 square feet lot? Maybe, but such extreme values are more likely due to measurement errors (e.g., wrong units, "999" used to indicate missing values, incorrect decimal places, etc.). I'll remove values whose $Z$-score lie outside of $\pm 5$ as they might indicate measurement errors. From the histograms above, this threshold should allow us to remove the few extreme values without loosing too many data points.

# %%
# Replace values whose absoluate Z score >= 5 with missing values
for col in continuous_cols:
    outliers = np.abs(stats.zscore(df_train[col])) >= 5
    df_train.loc[outliers, col] = np.nan

# %% [markdown]
# Now let's visualize the new transformed values.

# %%
# Transform continuous variables
scaler = preprocessing.StandardScaler().fit(df_train[continuous_cols])

# Generate histograms of Z-scores
plt.figure(figsize=(35, 25))

for i in range(len(continuous_cols)):
    plt.subplot(7, 5, i + 1)
    plt.hist(scaler.transform(df_train[continuous_cols])[:, i])
    plt.title("{}".format(continuous_cols[i]))

plt.tight_layout
plt.show()

# %% [markdown]
# We can see that many extreme values are no longer there. Let's move on to explore relationships between variables.

# %% [markdown]
# ### Data exploration

# %% [markdown]
# #### Univariate analysis
# First of all, let's examine our target variable, "saleprice".

# %%
df_train["saleprice"].describe()
# Out:
# count      1165.000000
# mean     179041.224893
# std       75031.355895
# min       35311.000000
# 25%      129900.000000
# 50%      162000.000000
# 75%      213000.000000
# max      556581.000000
# Name: saleprice, dtype: float64

# %% [markdown]
# The lowest housing price is 35,111 and the highest is 556,581. So far nothing seems out of the ordinary.

# %%
# Distribution of housing prices
plt.figure(figsize=(5, 5))

sns.distplot(df_train["saleprice"].dropna())
plt.xlabel("Housing price (USD)")
plt.ylabel("Probability desnity")
plt.title("Distrubution of housing prices")

plt.show()

# Kkewness and kurtosis of the distribution
print("Skewness: %f" % df_train["saleprice"].skew())
print("Kurtosis: %f" % df_train["saleprice"].kurt())
# Out:
# Skewness: 1.443106
# Kurtosis: 2.882099

# %% [markdown]
# It's important for many models that the target variable is normally distributed. We can check normality using skewness and kurtosis. Skewness measures the asymmetry of a probability distribution and a value larger than 1 or smaller than -1 suggests that a distribution is highly skewed. And according to [Wikipedia](https://en.wikipedia.org/wiki/Kurtosis), Kurtosis measures the "tailedness" of a probability distribution and a value larger than 3 indicates that a distribution is heavy tailed. By both standards, the housing price distribution is not normal but rather right skewed.
#
# Luckily, we can use log transformation to normalize right-skewed (but not left-skewed) distributions quite effectively. We can create a new variable called "saleprice_log" to store the log transformed prices.

# %%
df_train["saleprice_log"] = np.log(df_train["saleprice"])

# %%
# Distribution of log(housing prices)
plt.figure(figsize=(5, 5))

sns.distplot(df_train["saleprice_log"].dropna())
plt.xlabel("Log of housing price (USD)")
plt.ylabel("Probability desnity")
plt.title("Distrubution of log(housing prices)")

plt.show()

# Skewness and kurtosis of the new distribution
print("Skewness: %f" % df_train["saleprice_log"].skew())
print("Kurtosis: %f" % df_train["saleprice_log"].kurt())
# Out:
# Skewness: 0.082920
# Kurtosis: 0.567431

# %% [markdown]
# We can check that the new distribution is normally distributed. The old column can be dropped from the training data as it's no longer needed.

# %%
# Drop the raw sale prices
df_train.drop("saleprice", axis=1, inplace=True)

# %% [markdown]
# For other continuous values, we can similarly check for skweness and kurtosis.

# %%
for col in continuous_cols[:-1]:
    print(
        "{:15}".format(col),
        "Skewness: {:05.2f}".format(df_train[col].skew()),
        "   ",
        "Kurtosis: {:06.2f}".format(df_train[col].kurt()),
    )
# Out:
# lotarea         Skewness: 03.79     Kurtosis: 025.38
# overallqual     Skewness: 00.27     Kurtosis: -00.02
# overallcond     Skewness: 00.71     Kurtosis: 000.95
# yearbuilt       Skewness: -0.59     Kurtosis: -00.47
# yearremodadd    Skewness: -0.47     Kurtosis: -01.30
# masvnrarea      Skewness: 02.52     Kurtosis: 008.18
# bsmtfinsf1      Skewness: 00.79     Kurtosis: -00.09
# bsmtfinsf2      Skewness: 03.71     Kurtosis: 013.61
# bsmtunfsf       Skewness: 00.92     Kurtosis: 000.47
# totalbsmtsf     Skewness: 00.65     Kurtosis: 002.25
# firstflrsf      Skewness: 00.83     Kurtosis: 000.68
# secondflrsf     Skewness: 00.80     Kurtosis: -00.62
# lowqualfinsf    Skewness: 14.71     Kurtosis: 232.34
# grlivarea       Skewness: 00.88     Kurtosis: 001.16
# bsmtfullbath    Skewness: 00.70     Kurtosis: -00.61
# bsmthalfbath    Skewness: 03.81     Kurtosis: 012.54
# fullbath        Skewness: 00.08     Kurtosis: -00.89
# halfbath        Skewness: 00.70     Kurtosis: -01.03
# bedroomabvgr    Skewness: 00.08     Kurtosis: 001.31
# kitchenabvgr    Skewness: 04.37     Kurtosis: 017.13
# totrmsabvgrd    Skewness: 00.69     Kurtosis: 000.94
# fireplaces      Skewness: 00.68     Kurtosis: -00.12
# garageyrblt     Skewness: -0.63     Kurtosis: -00.41
# garagecars      Skewness: -0.34     Kurtosis: 000.10
# garagearea      Skewness: 00.27     Kurtosis: 001.02
# wooddecksf      Skewness: 01.39     Kurtosis: 001.88
# openporchsf     Skewness: 01.79     Kurtosis: 003.47
# enclosedporch   Skewness: 02.90     Kurtosis: 007.66
# threessnporch   Skewness: 15.50     Kurtosis: 241.41
# screenporch     Skewness: 03.90     Kurtosis: 014.35
# poolarea        Skewness: 00.00     Kurtosis: 000.00
# miscval         Skewness: 09.11     Kurtosis: 102.46
# mosold          Skewness: 00.22     Kurtosis: -00.41
# yrsold          Skewness: 00.08     Kurtosis: -01.19

# %% [markdown]
# Quite a few variables are skewed and/or heavy tailed. Like before, we can log transform highly right-skewed distributions (skewness > 1) to normalize them and drop the old columns afterwards.

# %%
for col in continuous_cols[:-1]:
    if df_train[col].skew() > 1:
        df_train[col + "_log"] = np.log(df_train[col])
        df_train.drop(col, inplace=True, axis=1)

# %% [markdown]
# For discrete variables (not including "id"), we can check for class imbalance. Since we're building linear regression models rather than classification models, class imbalance isn't a huge problem if it's not too extreme (e.g., 10000:1, see [discussions](https://mathoverflow.net/questions/53541/how-to-construct-a-linear-regression-model-with-an-unbalanced-sample-design)).

# %%
# Names of discrete columns
discrete_cols = df_train.select_dtypes(include=["object"]).columns

# %%
# Generate countplots for discrete variables
plt.figure(figsize=(40, 40))

i = 1
for col in discrete_cols:
    plt.subplot(8, 6, i)
    sns.countplot(x=col, data=df_train[discrete_cols])
    plt.title("{}".format(col))
    i += 1

plt.tight_layout
plt.show()

# %% [markdown]
# As we can see, while class imbalance is quite obvious in almost all cases, it's not considered too extreme for regression models.

# %% [markdown]
# #### Bivariate analysis
# First, let's examine the relationship between each continuous variable and our target variable, saleprice_log .

# %%
# Names of continuous columns
continuous_cols = df_train.select_dtypes(include=["number"]).columns

# %%
# Generate regression plots
plt.figure(figsize=(35, 35))

i = 1
for col in continuous_cols:
    plt.subplot(7, 5, i)
    sns.regplot(x=col, y="saleprice_log", data=df_train[continuous_cols], fit_reg=True)
    i += 1

plt.tight_layout
plt.show()

# %% [markdown]
# Some variables are strongly correlated with saleprice_log, such as "overallqual" (rates the overall material and finish of the house) and "grlivarea" (above ground living area square feet). Intuitively, if I were to buy a house, I would also care very much about how big the house is and whether it's of high quality. These values are good candidates for predicting housing prices.
#
# Some variables such as "mosold", "yrsold", etc. don't seem to have much influence on sale prices. Some (e.g., "threessnporch", "poolarea") have fixed values and can't possibly be used as predictors. We can exclude these variables by imposing a threshold on correlation coefficients (e.g., r >= .04).

# %%
# Set the threshold to be r = 0.4
thresh = 0.4

# Compute pairwise correlations
corr = df_train[continuous_cols].corr()

# Absolute values of correlation coefficients
corr_abs = corr.abs()

# Correlations with target variable, ranked
corr_target = corr_abs.nlargest(len(continuous_cols), "saleprice_log")["saleprice_log"]

# Drop variables with weak correlations
below_continuous = list(corr_target[corr_target.values < thresh].index)
above_continuous = list(corr_target[corr_target.values >= thresh].index)

df_train = df_train.drop(below_continuous, axis=1)

# %% [markdown]
# Out of caution, let's check if all continuous variables are included in the calculation.

# %%
print(
    "{} variables above or below the threshold.".format(
        len(above_continuous) + len(below_continuous)
    )
)

print("There are {} continuous variables in total.".format(len(continuous_cols)))
# Out:
# 33 variables above or below the threshold.
# There are 35 continuous variables in total.

# %% [markdown]
# "poolarea" and "bsmthalfbath_log" are missing. Because they are invariant, correlations can't be defined. We should exclude them as well.

# %%
df_train = df_train.drop(["poolarea", "bsmthalfbath_log"], axis=1)
df_test = df_test.drop(["poolarea", "bsmthalfbath"], axis=1)

# %% [markdown]
# We need to drop rest of the below-threshold columns in the test data as well.

# %%
# Original names of these columns
below_continuous_old = [
    col.replace("_log", "") if "log" in col else col for col in below_continuous
]

# Drop them in the test data
df_test = df_test.drop(below_continuous_old, axis=1)

# %% [markdown]
# For discrete variables, we can use box plots to check if saleprice_log differs by category.

# %%
# Generate countplots for discrete variables
plt.figure(figsize=(40, 40))

i = 1
for col in discrete_cols:
    plt.subplot(8, 6, i)
    sns.boxplot(
        x=col,
        y="saleprice_log",
        data=df_train[discrete_cols.tolist() + ["saleprice_log"]],
    )
    plt.title("{}".format(col))
    i += 1

plt.tight_layout
plt.show()

# %% [markdown]
# Some variables (e.g., "mszoning", "salecondition") seem to have strong influence on housing prices while others (e.g., "lotconfig") barely do. To filter out variables with little impact in a more precious manner, we can assign a numeric value to each category using [label encoding](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html) (each category is assigned a unique number ranging from 0 to the number of classes - 1) and examine how well each variable correlates with saleprice_log.
#
# Granted, label encoding creates ordinality that doesn't exist in our nominal data. For example, gravel roads aren't larger than paved roads, even though the former are assign 1 and the latter 0. As long as we don't interpret data in an ordinal manner, it should be fine. Compared to [one hot encoding](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html) that creates one variable for each category, label encoding allows us to quickly calculate correlations and use them to select features.

# %%
# Label encode categorical variables
le = preprocessing.LabelEncoder()

for col in discrete_cols:
    le.fit(df_train[col])
    df_train[col + "_num"] = le.transform(df_train[col])
    df_train.drop(col, axis=1, inplace=True)

# Names of new columns
new_cols = [col + "_num" for col in discrete_cols]

# %%
# Generate regression plots
plt.figure(figsize=(40, 40))

i = 1
for col in new_cols:
    plt.subplot(8, 6, i)
    sns.regplot(x=col, y="saleprice_log", data=df_train, fit_reg=True)
    i += 1

plt.tight_layout
plt.show()

# %% [markdown]
# Like before, we can drop variables that are only weakly correlated (r < 0.4) with saleprice_log.

# %%
# Set the threshold to be r = 0.4
thresh = 0.4

# Compute pairwise correlations
corr = df_train[new_cols + ["saleprice_log"]].corr()

# Absolute values of correlation coefficients
corr_abs = corr.abs()

# Correlations with target variable, ranked
corr_target = corr_abs.nlargest(len(new_cols) + 1, "saleprice_log")["saleprice_log"]

# Drop variables with weak correlations
below_discrete = list(corr_target[corr_target.values < thresh].index)
above_discrete = list(corr_target[corr_target.values >= thresh].index)

df_train = df_train.drop(below_discrete, axis=1)

# %% [markdown]
# Remove these columns from the test data as well.

# %%
# Original names of columns below threshold
below_discrete_old = [col.replace("_num", "") for col in below_discrete]

# Drop these from the test data
df_test = df_test.drop(below_discrete_old, axis=1)

# %%
# Shape of current data
df_train.shape
# Out:
# (1168, 21)

# %% [markdown]
# After dropping variables weakly correlated with saleprice_log, we still have 20 left (not including the target). Even though each variable is moderately to strongly correlated with the target, we may not need every single one of them. For instance, if we've already included the total living area above ground, we may not need the area of each floor. Next, I'll select variables that may have unique contributions to regression models.

# %% [markdown]
# ### Feature engineering
# Not all variables are useful features for predicting housing prices. Selecting the right features is essential for building successful models. Ideally, we want to find features that are highly correlated with the target variable and distinct from each other. How can we achieve this? As Abhini Shetye summarized in her [Medium article](https://towardsdatascience.com/feature-selection-with-pandas-e3690ad8504b), there are 3 common methods: filter methods, wrapper methods, and embedded methods.
#
# But first off, let's examine the relationships among the 21 remaining variables.

# %% [markdown]
# #### Correlation matrix
# We can do so by generating a heat map of the correlation matrix of all the variables.

# %%
# Correlation matrix of all 21 variables
corr = df_train.corr()

# Plot Pearson correaltion coefficients on a heat map
plt.figure(figsize=(10, 10))

ax = sns.heatmap(
    corr,
    vmin=-1,
    vmax=1,
    center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment="right")

plt.show()

# %% [markdown]
# #### Filter method

# %% [markdown]
# Using the filter method, we can drop features that are weakly correlated with the target. This time, we can set a stricter threshold of r = 0.5.

# %%
# Correlations with target variable
cor_target = abs(corr["saleprice_log"])

# Selecting highly correlated features
relevant_features = cor_target[cor_target > 0.5]

print(
    "{} features are highly correlated (r >= 0.5) with saleprice_log.".format(
        len(relevant_features)
    )
)
# Out:
# 16 features are highly correlated (r >= 0.5) with saleprice_log.

# %% [markdown]
# Another concern is that some features are highly correlated with one another, a notable case being "yearbuilt" and "garageyrblt". This is understandable since a house is usually built at the same time as its garage. We need only keep one of several highly correlated features.

# %%
# Correlation matrix of revelant feature
relevant_corr = corr[relevant_features.index.tolist()]

# Select upper triangle of the new correlation matrix
upper = relevant_corr.where(np.triu(np.ones(relevant_corr.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.8
to_drop = [col for col in upper.columns if any(upper[col] > 0.8)]

print("The redudant features are: {}.".format(to_drop))
# Out:
# The redudant features are: ['totrmsabvgrd', 'garageyrblt', 'saleprice_log'].

# %% [markdown]
# Of course saleprice_log is prefectly correlated with itself. Among the explanatory variables, "totrmsabvgrd" and "garageyrblt" are highly correlated with other features and therefore not worth keeping. Below is the list of best features according to Pearson correlations.

# %%
# Features highly correlated with target and distinct from one another
features_list = relevant_features.index.drop(to_drop).tolist()

print(
    "{} features ({}) can be used to predict housing prices.".format(
        len(features_list), features_list
    )
)
# Out:
# 13 features (['overallqual', 'yearbuilt', 'yearremodadd', 'totalbsmtsf', 'firstflrsf', 'grlivarea', 'fullbath', 'garagecars', 'garagearea', 'lowqualfinsf_log', 'exterqual_num', 'bsmtqual_num', 'kitchenqual_num']) can be used to predict housing prices.

# %% [markdown]
# Filtering by Pearson correlations is fast but imprecise. We can fine tune the list above to further remove "bad" features.

# %% [markdown]
# #### Wrapper method
# Common wrapper methods include backward elimination that iteratively removes the worst performing features and recursive feature elimination (RFE) that keeps a required number of features. Backward elimination is simple but statisticians often [argue against](https://statmodeling.stat.columbia.edu/2014/06/02/hate-stepwise-regression/) such stepwise selection because it uses unconstrained least squares to calculate model fit, which can be problematic. RFE asks for a fixed number of features, which isn't what we want here.
#
# Because of these shortcomings, I won't use wrapper methods for feature selection.

# %% [markdown]
# #### Embedded method
# Lasso regularization is considered one of the best methods for feature selection. It penalizes the coefficients of irrelevant features. If a feature's coefficient is 0, it will be removed from the feature list. Let's get back to the fuller set of 21 features and perform Lasso regularization.
#
# Like many methods, Lasso cannot handle infinity or missing values, so we need to deal with them first.

# %%
# Replace infinity with missing values
df_train = df_train.replace([np.inf, -np.inf], np.nan)

# Find columns with missing data
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum() / df_train.isnull().count()).sort_values(
    ascending=False
)
missing = pd.concat([total, percent], axis=1, keys=["total", "percent"])
missing = missing.loc[missing["total"] > 0, :]

missing
# Out:
#                   total   percent
# lowqualfinsf_log   1160  0.993151
# garageyrblt          62  0.053082
# lotarea_log           4  0.003425
# firstflrsf            3  0.002568
# saleprice_log         3  0.002568
# grlivarea             3  0.002568
# totalbsmtsf           1  0.000856

# %% [markdown]
# Since "lowqualfinsf_log" is mostly missing, we can drop it. Later we should do this for the test data as well.

# %%
df_train = df_train.drop("lowqualfinsf_log", axis=1)

# %% [markdown]
# Since there are only a few missing values, we can remove rows with missing values without losing much power.

# %%
df_train = df_train.dropna()

# %% [markdown]
# Perform Lasso regression on the new data frame.

# %%
# Target vector
y = df_train["saleprice_log"]

# Feature vectors
X = df_train.loc[:, df_train.columns != "saleprice_log"]


# Lasso regularization
reg = LassoCV()
reg.fit(X, y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" % reg.score(X, y))
coef = pd.Series(reg.coef_, index=X.columns)
# Out:
# Best alpha using built-in LassoCV: 0.129655
# Best score using built-in LassoCV: 0.810310

# %% [markdown]
# Which features are picked by Lasso and which ones are eliminated?

# %%
# Number of features picked and eliminated
print(
    "Lasso picked "
    + str(sum(coef != 0))
    + " variables and eliminated the other "
    + str(sum(coef == 0))
    + " variables"
)

# Plot feature importance
imp_coef = coef.sort_values()
import matplotlib

matplotlib.rcParams["figure.figsize"] = (8.0, 10.0)
imp_coef.plot(kind="barh")
plt.title("Feature importance using Lasso Model")

plt.show()
# Out:
# Lasso picked 5 variables and eliminated the other 14 variables

# %% [markdown]
# Most features are deemed unimportant by Lasso, except for "yearremodadd", "yearbuilt", "grlivarea", "totalbsmtsf", and "garagearea". This result aligns with our intuition that size and age probably matter the most for housing prices.

# %% [markdown]
# ## Regression models

# %% [markdown]
# Finally, we can use the above features to predict housing prices! Let's try and compare different regression methods.

# %%
features_final = ["yearremodadd", "yearbuilt", "grlivarea", "totalbsmtsf", "garagearea"]

# %% [markdown]
# ### Linear regression
# To begin, we can fit a simple linear regression model using `LinearRegression()` in scikit-learn.

# %% [markdown]
# #### Train model

# %%
# Target variable
y = df_train["saleprice_log"]

# Feature vectors
X = df_train[features_final]

# Create a LinearRegression model object
lrm = LinearRegression()

# Estimate coefficients using OLS
lrm.fit(X, y)

# Display results
print("\nCoefficients: \n", lrm.coef_)
print("\nIntercept: \n", lrm.intercept_)
# Out:
# Coefficients:
#  [0.0033364  0.00294306 0.00038352 0.00023775 0.00018528]
#
# Intercept:
#  -1.311507071807826

# %% [markdown]
# #### Cross validation
# We can use $k$-fold cross validation to check model performance, especially to guard against overfitting. To do so, we will split the training data into $k$ groups and in turn use each group as the test dataset to evaluate the model trained on the other ($k-1$) groups. A popular choice of $k$ is 10. The `cross_val_score` module in scikit-learn implements this process easily.
#
# Of course, we can use many different evaluation [metrics](https://scikit-learn.org/stable/modules/model_evaluation.html), such as mean absolute error (MAE), mean squared error (MSE), root mean squared error (RMSE), mean absolute percentage error (MAPE), etc.. For predictive modeling, RMSE is the most commonly used metric. By definition, RMSE is the square root of the variance of residuals and lower values indicate better fit.

# %%
scores = cross_val_score(lrm, X, y, scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)

print(
    "For linear regression: RMSE of each fold is {} and the mean is {}.".format(
        rmse_scores, rmse_scores.mean()
    )
)
# Out:
# For linear regression: RMSE of each fold is [0.18064918 0.15095205 0.15553903 0.16357003 0.16002581 0.17191612
#  0.16905208 0.16608345 0.16421899 0.15904345] and the mean is 0.16410501754545828.

# %% [markdown]
# ### Regularized regression
#
# To prevent overfitting, we can apply [regularization techniques](https://towardsdatascience.com/over-fitting-and-regularization-64d16100f45c?) where we discourage model complexity by penalizing the loss function. Different techniques have different penalty terms. L1 regularization penalizes the absolute value of feature weights, an example being Lasso regression. L2 regularization like Ridge regression penalizes the sum of square of all feature weights. ElasticNet regression is a hybrid of Lasso and Ridge and usually does a better job at preventing overfitting. We can fit our house price model using each of these techniques.

# %% [markdown]
# #### Hyperparameter tuning
# Apart from the linear regression model, the other models all have hyperparameters. Both Lasso and Ridge regressions have one hyperparameter $\alpha$ that controls the amount of regularization. The larger the $\alpha$, the more feature coefficients are 0. ElasticNet regression additionally have a hyperparameter "L1 ratio" that controls the weights of L1 and L2 regressions; when L1 ratio is equal to 1, ElasticNet regression becomes Lasso. Before fitting the models, let's find the best hyperparameters to use.

# %%
# Use K-fold cross validation to select hyperparameters
ridge_cv = RidgeCV(alphas=[0.01, 0.1, 1.0, 10.0])

lasso_cv = LassoCV(alphas=[0.01, 0.1, 1.0, 10.0])

elastic_cv = ElasticNetCV(
    eps=None,
    n_alphas=None,
    alphas=[0.01, 0.1, 1.0, 10.0],
    l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1.0],
    cv=5,
)

print("The best alpha for Ridge is {}.\n".format(regr_cv.fit(X, y).alpha_))

print("The best alpha for Lasso is {}.\n".format(lasso_cv.fit(X, y).alpha_))

print(
    "The best alpha for ElasticNet is {} and the best l1_ratio is {}.".format(
        elastic_cv.fit(X, y).alpha_, elastic_cv.fit(X, y).l1_ratio_
    )
)
# Out:
# The best alpha for Ridge is 10.0.
#
# The best alpha for Lasso is 0.01.
#
# The best alpha for ElasticNet is 0.1 and the best l1_ratio is 0.1.

# %% [markdown]
# #### Train models
# Now we can use the proper hyperparameters to train the regularized regression models.

# %%
# Create model objectS
lasso = Lasso(alpha=0.01)
ridge = Ridge(alpha=10.0)
elastic = ElasticNet(alpha=0.1, l1_ratio=0.1)

# Estimate coefficients
lasso.fit(X, y)
ridge.fit(X, y)
elastic.fit(X, y)

# Display results
print("\nLasso coefficients: \n", lasso.coef_)
print("\nLasso intercept: \n", lasso.intercept_)
print("\nRidge coefficients: \n", ridge.coef_)
print("\nRidge intercept: \n", ridge.intercept_)
print("\nElasticNet coefficients: \n", elastic.coef_)
print("\nElasticNet intercept: \n", elastic.intercept_)
# Out:
# Lasso coefficients:
#  [0.00331217 0.00293831 0.00038361 0.00023798 0.00018604]
#
# Lasso intercept:
#  -1.2548072816415488
#
# Ridge coefficients:
#  [0.00333632 0.00294305 0.00038352 0.00023775 0.00018528]
#
# Ridge intercept:
#  -1.3113298490538874
#
# ElasticNet coefficients:
#  [0.00331137 0.00293822 0.00038361 0.00023798 0.00018607]
#
# ElasticNet intercept:
#  -1.2530704720850245

# %% [markdown]
# #### Cross validation

# %%
scores_lasso = cross_val_score(lasso, X, y, scoring="neg_mean_squared_error", cv=10)
rmse_lasso = np.sqrt(-scores_lasso)

scores_ridge = cross_val_score(ridge, X, y, scoring="neg_mean_squared_error", cv=10)
rmse_ridge = np.sqrt(-scores)

scores_elastic = cross_val_score(elastic, X, y, scoring="neg_mean_squared_error", cv=10)
rmse_elastic = np.sqrt(-scores)

print(
    "For Lasso regression: \nRMSE of each fold is {} and the mean is {}.".format(
        rmse_lasso, rmse_lasso.mean()
    )
)

print(
    "\nFor Ridge regression: \nRMSE of each fold is {} and the mean is {}.".format(
        rmse_ridge, rmse_ridge.mean()
    )
)

print(
    "\nFor ElasticNet regression: \nRMSE of each fold is {} and the mean is {}.".format(
        rmse_elastic, rmse_elastic.mean()
    )
)

print(
    "\nFor linear regression: \nRMSE of each fold is {} and the mean is {}.".format(
        rmse_scores, rmse_scores.mean()
    )
)
# Out:
# For Lasso regression:
# RMSE of each fold is [0.18076049 0.1509443  0.15545182 0.16366005 0.16009171 0.17185704
#  0.16908885 0.16601376 0.1641953  0.15898696] and the mean is 0.16410502745964267.
#
# For Ridge regression:
# RMSE of each fold is [0.18064918 0.15095205 0.15553903 0.16357003 0.16002581 0.17191612
#  0.16905208 0.16608345 0.16421899 0.15904345] and the mean is 0.16410501754545828.
#
# For ElasticNet regression:
# RMSE of each fold is [0.18064918 0.15095205 0.15553903 0.16357003 0.16002581 0.17191612
#  0.16905208 0.16608345 0.16421899 0.15904345] and the mean is 0.16410501754545828.
#
# For linear regression:
# RMSE of each fold is [0.18064918 0.15095205 0.15553903 0.16357003 0.16002581 0.17191612
#  0.16905208 0.16608345 0.16421899 0.15904345] and the mean is 0.16410501754545828.

# %% [markdown]
# ### Best model
# According to 10-fold cross validation, all models performed similarly. However, the real test is whether our models can accurately predict house prices in the test data that we've saved up from earlier.

# %% [markdown]
# ## Predict house prices

# %% [markdown]
# ### Prepare test data
# Since we used saleprice_log to train models, we should similarly log transform saleprice in the test data.

# %%
df_test["saleprice_log"] = np.log(df_test["saleprice"])

# %% [markdown]
# Because none of the 5 chosen features were transformed values, we can directly select these columns from the test data.

# %%
# Target variable
test_y = df_test["saleprice_log"]

# Feature vectors
test_X = df_test[features_final]

# %% [markdown]
# ### Make predictions
# Now we can use each regression model trained on the training data to predict house prices in the test data.

# %%
predict_lrm = lrm.predict(test_X)
predict_lasso = lasso.predict(test_X)
predict_ridge = ridge.predict(test_X)
predict_elastic = elastic.predict(test_X)

# %% [markdown]
# ### Evaluate predictions
# We can compare model predictions with actual house prices. Like before, we can use RMSE for model evaluation.

# %%
rmse_test_lrm = np.sqrt(metrics.mean_squared_error(test_y, predict_lrm))
rmse_test_lasso = np.sqrt(metrics.mean_squared_error(test_y, predict_lasso))
rmse_test_ridge = np.sqrt(metrics.mean_squared_error(test_y, predict_ridge))
rmse_test_elastic = np.sqrt(metrics.mean_squared_error(test_y, predict_elastic))

print("Linear regression: RMSE = {}.\n".format(rmse_test_lrm))
print("Lasso regression: RMSE = {}.\n".format(rmse_test_lasso))
print("Ridge regression: RMSE = {}.\n".format(rmse_test_ridge))
print("Elastic regression: RMSE = {}.\n".format(rmse_test_elastic))
# Out:
# Linear regression: RMSE = 0.16658180115248547.
#
# Lasso regression: RMSE = 0.16660221823854876.
#
# Ridge regression: RMSE = 0.16658183092904688.
#
# Elastic regression: RMSE = 0.1666025657919602.

# %% [markdown]
# Overall, RMSE is low for all 4 models, suggesting that they all make highly accurate predictions about house prices. Perhaps a bit surprisingly, the linear regression model performed slightly better than the 3 regularized regression models. This may be because we already used Lasso regularization to select features so further regularization is no longer needed. If we didn't go through feature engineering and used the full set of features, Lasso, Ridge, and ElasticNet should outperform linear regression.

# %% [markdown]
# ## Summary

# %% [markdown]
# ### Features used

# %% [markdown]
# The original house price dataset has 79 explanatory variables. After removing variables that were only weakly correlated with our target variable, the log of house prices in Ames (saleprice_log) and using Lasso regularization to filter unimportant features, we ended up with 5 features that potentially have the highest predictive power:
# - "yearremodadd": Remodel date
# - "yearbuilt": Original construction date
# - "grlivarea": Above grade (ground) living area square feet
# - "totalbsmtsf": Total square feet of basement area
# - "garagearea": Size of garage in square feet
#
# Since we were already selective about which features to include, both our linear regression and regularized regression (Lasso, Ridge, and ElasticNet) models were able to predict house prices in the test data accurately. This feature list also makes intuitive sense. When buying a house ourselves, we'll probably first think about whether the house is new or recently remodeled and how large the living area, basement, and garage we'll have. Factors like the masonry veneer type may never cross our mind.

# %% [markdown]
# ### External factors?
#
# Of course, we don't just care about the house itself when making such a big decision but also its surroundings. If we have kids, for instance, then it matters a lot whether the house is in a good school district or not. Other environmental factors such as crime rates in the neighborhood, access to public transportation and freeways, distant to the business district, etc. all seem to play a role. Unfortunately, since the Ames house price dataset doesn't have location information (e.g., street address), it's impossible to add these factors directly to each observation (which is a unique home). In the future, I'd like to examine how these factors might play a role in determining and predicting house prices.
